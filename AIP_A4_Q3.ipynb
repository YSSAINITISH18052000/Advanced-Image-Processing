# %% [markdown]
# #**Question 3**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
from google.colab import drive
from torchvision.transforms import Resize
from PIL import Image

# %% [markdown]
# **#preprocessing the dataset**

# %%
data_set_path = '/content/drive/MyDrive/object_detection'

# %%
# clone YOLOv5 repository
# !git clone https://github.com/ultralytics/yolov5  # clone repo
# %cd yolov5
# !git reset --hard 064365d8683fd002e9ad789c1e91fa3d021b44f0
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 15393, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (18/18), done.
# remote: Total 15393 (delta 9), reused 17 (delta 6), pack-reused 15369
# Receiving objects: 100% (15393/15393), 14.37 MiB | 31.99 MiB/s, done.
# Resolving deltas: 100% (10522/10522), done.
# /content/yolov5
# HEAD is now at 064365d Update parse_opt() in export.py to work as in train.py (#10789)

# %%
# %cd /content/yolov5/
# Out:
# /content/yolov5

# %%
# install dependencies as necessary
# !pip install -qr requirements.txt  # install dependencies (ignore errors)
import torch

from IPython.display import Image, clear_output  # to display images
from utils.downloads import attempt_download  # to download models/datasets

# clear_output()
print('Setup complete. Using torch %s %s' % (torch.__version__, torch.cuda.get_device_properties(0) if torch.cuda.is_available() else 'CPU'))
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 14.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 81.3 MB/s eta 0:00:00
# Setup complete. Using torch 2.0.0+cu118 _CudaDeviceProperties(name='Tesla T4', major=7, minor=5, total_memory=15101MB, multi_processor_count=40)

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data /content/drive/MyDrive/object_detection/data.yaml --cfg /content/yolov5/models/yolov5s.yaml --weights '' --name Assignement_4_YOLOv5 --cache
# Out:
# 2023-04-10 12:17:06.032902: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-04-10 12:17:07.282622: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ...

# %%
# !python val.py --img 640 --batch 16 --task 'val' --data /content/drive/MyDrive/object_detection/data.yaml --weights /content/drive/MyDrive/object_detection/runs/train/Assignement_4_YOLOv5/weights/best.pt
# Out:
# val: data=/content/drive/MyDrive/object_detection/data.yaml, weights=['/content/drive/MyDrive/object_detection/runs/train/Assignement_4_YOLOv5/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-72-g064365d Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /content/drive/.shortcut-targets-by-id/1R1PeYIoSz0SZwqsdq8ncNakQU3xKhses/object_detection/val/labels... 230 images, 31 backgrounds, 0 corrupt: 100% 230/230 [00:42<00:00,  5.44it/s]
# ...

# %%
# !python val.py --img 640 --batch 16 --task 'test' --data /content/drive/MyDrive/object_detection/data.yaml --weights /content/drive/MyDrive/object_detection/runs/train/Assignement_4_YOLOv5/weights/best.pt
# Out:
# val: data=/content/drive/MyDrive/object_detection/data.yaml, weights=['/content/drive/MyDrive/object_detection/runs/train/Assignement_4_YOLOv5/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-72-g064365d Python-3.9.16 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7037095 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /content/drive/.shortcut-targets-by-id/1R1PeYIoSz0SZwqsdq8ncNakQU3xKhses/object_detection/test/labels.cache... 104 images, 3 backgrounds, 0 corrupt: 100% 107/107 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 7/7 [00:07<00:00,  1.04s/it]
# ...
